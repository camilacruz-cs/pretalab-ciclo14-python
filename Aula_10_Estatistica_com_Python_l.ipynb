# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacruz-cs/pretalab-ciclo14-python/blob/main/Aula_10_Estatistica_com_Python_l.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conceitos Básicos de Estatística em Python
#
# ## Objetivos da aula
# - Compreender os principais conceitos de estatística descritiva.
# - Calcular medidas de tendência central e dispersão usando Python.
# - Visualizar distribuições de dados com Pandas, NumPy e Matplotlib.

# %% [markdown]
# ## 1. Introdução à Estatística Descritiva
#
# A **estatística descritiva** é o ramo da estatística que organiza, resume e interpreta conjuntos de dados.
#
# ## 2. Preparando o ambiente

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração de estilo
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 3. Criando um conjunto de dados de exemplo
#
# Vamos simular um conjunto de notas de alunas em uma disciplina.

# %%
# Gerar dados simulados de notas
np.random.seed(42)
notas = np.random.normal(loc=70, scale=10, size=50)  # média 70, desvio 10
df = pd.DataFrame({'nota': notas})

# %%
df.head()
# Out:
#         nota
# 0  74.967142
# 1  68.617357
# 2  76.476885
# 3  85.230299
# 4  67.658466

# %% [markdown]
# ## Estatísticas Resumidas com Pandas

# %%
df.describe()
# Out:
#             nota
# count  50.000000
# mean   67.745261
# std     9.336688
# min    50.403299
# 25%    61.390209
# 50%    67.658548
# 75%    73.362756
# max    88.522782

# %% [markdown]
# ## 4. Medidas de Tendência Central
#
# Essas medidas indicam valores típicos ou centrais de um conjunto de dados.

# %%
df['nota'].mean()
# Out:
# np.float64(67.7452609474386)

# %%
df['nota'].median()
# Out:
# 67.65854834163741

# %%
df['nota'].mode()
# Out:
# 0     50.403299
# 1     50.867198
# 2     52.369598
# 3     52.750822
# 4     55.214780
# 5     55.752518
# 6     55.876963
# 7     56.718140
# 8     57.791564
# 9     58.490064
# 10    59.422891
# 11    59.871689
# 12    60.919759
# 13    62.801558
# 14    63.982934
# 15    63.993613
# 16    64.377125
# 17    64.556173
# 18    65.305256
# 19    65.342702
# 20    65.365823
# 21    65.393612
# 22    66.988963
# 23    67.083063
# 24    67.658466
# 25    67.658630
# 26    67.742237
# 27    68.617357
# 28    68.843517
# 29    69.865028
# 30    70.675282
# 31    71.109226
# 32    71.713683
# 33    71.968612
# 34    72.088636
# 35    72.419623
# 36    73.142473
# 37    73.436183
# 38    73.756980
# 39    74.967142
# 40    75.425600
# 41    76.476885
# 42    77.384666
# 43    77.674347
# 44    78.225449
# 45    80.571222
# 46    84.656488
# 47    85.230299
# 48    85.792128
# 49    88.522782
# Name: nota, dtype: float64

# %% [markdown]
# ### Interpretação:
#
# Média: valor médio das notas.
#
# Mediana: ponto central da distribuição (metade acima, metade abaixo).
#
# Moda: valor mais frequente (útil para dados categóricos).

# %% [markdown]
# ## 5. Medidas de Dispersão
#
# Essas medidas mostram o quanto os dados variam em torno da média.

# %%
df['nota'].var()
# Out:
# 87.17373942630934

# %%
df['nota'].std()
# Out:
# 9.336687818831116

# %%
#É a distância do ponto máximo até o ponto mínimo.

amplitude = df['nota'].max() - df['nota'].min()
amplitude
# Out:
# 38.11948308388714

# %% [markdown]
# ### Interpretação:
#
# Variância: quanto as notas se afastam da média (em unidades²).
#
# Desvio padrão: medida prática da dispersão, na mesma unidade da variável.
#
# Amplitude: diferença entre o maior e o menor valor.

# %% [markdown]
# http://leg.ufpr.br/~ara/teach/ebas/handout_04.html

# %% [markdown]
# ## 6. Medidas de Posição Relativa — Quartis e Percentis
#
# Essas medidas dividem os dados em partes iguais.

# %%
df['nota'].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
# 0.10    55.698744
# 0.25    61.390209
# 0.50    67.658548
# 0.75    73.362756
# 0.90    78.460026
# Name: nota, dtype: float64

# %% [markdown]
# ## 8. Medidas de Associação

# %%
# Exemplo: relação entre horas de estudo e nota
np.random.seed(42)
horas_estudo = np.random.normal(5, 1, 50)
notas = 60 + horas_estudo * 6 + np.random.normal(0, 3, 50)
df_notas = pd.DataFrame ( {'notas': notas, 'horas_estudo': horas_estudo})

# %%
df_notas
# Out:
#          notas  horas_estudo
# 0    93.952537      5.496714
# 1    88.015167      4.861736
# 2    91.855365      5.647689
# 3   100.973208      6.523030
# 4    91.688078      4.765847
# 5    91.389019      4.765863
# 6    96.957624      6.579213
# 7    93.676971      5.767435
# 8    88.176944      4.530526
# 9    96.181996      5.542560
# 10   85.781971      4.536582
# 11   86.648645      4.534270
# 12   88.132769      5.241962
# 13   74.931699      3.086720
# 14   82.088070      3.275082
# 15   90.694995      4.437712
# 16   83.706983      3.987169
# 17   94.896083      5.314247
# 18   85.636764      4.091976
# 19   79.590819      3.587696
# 20   99.878079      6.465649
# 21   93.259452      4.774224
# 22   90.297691      5.067528
# 23   86.145442      3.575252
# 24   78.874468      4.455617
# 25   93.131243      5.110923
# 26   83.355180      3.849006
# 27   91.357166      5.375698
# 28   86.671450      4.399361
# 29   82.287131      4.708306
# 30   85.730745      4.398293
# 31  102.185007      6.852278
# 32   94.352699      4.986503
# 33   82.098924      3.942289
# 34   92.509789      5.822545
# 35   81.169667      3.779156
# 36   93.999388      5.208864
# 37   79.228233      3.040330
# 38   80.441603      3.671814
# 39   92.720970      5.196861
# 40   94.722032      5.738467
# 41   93.934145      5.171368
# 42   87.199951      4.884352
# 43   87.210391      4.698896
# 44   79.952544      3.521478
# 45   81.290390      4.280156
# 46   88.124528      4.539361
# 47   97.125899      6.057122
# 48   92.077050      5.343618
# 49   78.717998      3.236960

# %% [markdown]
# **Correlação (Coeficiente de Pearson)**
#
# A correlação é uma versão padronizada da covariância, variando entre -1 e +1.
#
# http://www.leg.ufpr.br/~paulojus/estbas/slides/702_testes_de_correlacao.pdf

# %%
df_notas.corr()
# Out:
#                  notas  horas_estudo
# notas         1.000000      0.914448
# horas_estudo  0.914448      1.000000

# %% [markdown]
# #### Interpretação:
#
# +1: correlação positiva perfeita (ambas crescem juntas).
#
# -1: correlação negativa perfeita (uma sobe e a outra desce).
#
# 0: sem correlação linear.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='horas_estudo', y='notas', data=df_notas, color='teal')
plt.title('Relação entre horas de estudo e nota')
plt.xlabel('Horas de estudo')
plt.ylabel('Nota')
plt.show()

# %% [markdown]
# O gráfico de dispersão (scatter plot) mostra a direção e a força da relação:
#
# Se os pontos formam uma linha inclinada para cima → correlação positiva.
#
# Se formam uma linha inclinada para baixo → correlação negativa.
#
# Se estão espalhados sem padrão → correlação próxima de zero.

# %% [markdown]
# 💡 Dica prática
#
# Use:
#
# * .cov() para explorar como variáveis variam juntas;
#
# * .corr() para medir quão forte é essa relação.

# %% [markdown]
# ## Quarteto de Anscombe
# ![Anscombe's_quartet_3.svg.png](data:image/png;base64,...)
#
# https://pt.wikipedia.org/wiki/Quarteto_de_Anscombe

# %% [markdown]
# ## 9. Visualização de Distribuições

# %% [markdown]
# ### Histograma

# %%
plt.figure(figsize=(8,5))
plt.hist(df_notas['notas'], bins=10, color='teal', edgecolor='black')
plt.title('Distribuição das Notas')
plt.xlabel('Nota')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df_notas['notas'], color='orange')
plt.title('Boxplot das Notas')
plt.show()

# %% [markdown]
# O gráfico resultante mostra:
#
# A caixa (box) representa onde estão 50% dos dados centrais (entre Q1 e Q3).
#
# A linha dentro da caixa indica a mediana (Q2).
#
# Os “bigodes” (whiskers) mostram o alcance dos dados, até 1.5×IQR.
#
# Os pontos isolados são outliers, ou seja, valores muito abaixo ou acima da tendência geral.
#
# ----
#
# | Observação                                       | Interpretação                                         |
# | ------------------------------------------------ | ----------------------------------------------------- |
# | A caixa é estreita                               | Baixa dispersão (dados concentrados)                  |
# | A caixa é larga                                  | Alta dispersão (dados bem espalhados)                 |
# | A linha da mediana está próxima da base da caixa | Distribuição assimétrica à direita (média > mediana)  |
# | A linha da mediana está próxima do topo da caixa | Distribuição assimétrica à esquerda (média < mediana) |
# | Existem pontos fora dos “bigodes”                | Outliers (valores fora do padrão)                     |

# %% [markdown]
# ## Exercícios Práticos
# 1. Calcule média, mediana e moda de um conjunto de idades:
# idades = [23, 25, 31, 22, 28, 26, 30, 28, 22, 25, 29]
#
# 2. Gere 100 valores aleatórios com média 50 e desvio 8.
#
# 2.1 Calcule a variância e o desvio padrão.
#
# 2.2. Gere um gráfico de histograma e um boxplot com esses dados.
#
# 2.3. Interprete o que cada gráfico indica sobre a distribuição e a dispersão dos dados.

# %%
idades = pd.Series([23, 25, 31, 22, 28, 26, 30, 28, 22, 25, 29, 25])

# %%
media = idades.mean()
mediana = idades.median()
moda = idades.mode()

print(f"A média de idades é {media}")
print(f"A mediana das idades é {mediana}")
print(f"A moda das idades é {moda}")
# Out:
# A média de idades é 26.166666666666668
# A mediana das idades é 25.5
# A moda das idades é 0    25
# dtype: int64

# %%
#Gere 100 valores aleatórios com média 50 e desvio 8.

import numpy as np

np.random.seed(42)
valores = np.random.normal(loc = 50, scale =8, size=100)

# %%
#2.1 Calcule a variância e o desvio padrão.

desvio = np.std(valores)
variancia = np.var(valores)

print(f"O desvio padrão é de {desvio}")
print(f"A variância é de {variancia}")
# Out:
# O desvio padrão é de 7.2289294131570365
# A variância é de 52.25742046040694

# %%
#2.2. Gere um gráfico de histograma e um boxplot com esses dados.

plt.hist(valores, bins=15)
plt.xlabel('Dado')
plt.ylabel('Frequência')
plt.title('Distribuição dos Dados')
plt.show()

# %%
plt.boxplot(valores, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f95457d16d0>,
#   <matplotlib.lines.Line2D at 0x7f95457d20c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f95457d1ca0>,
#   <matplotlib.lines.Line2D at 0x7f95457d3ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9545831640>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f95457d0710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f95457d3200>],
#  'means': []}

# %%
sns.boxplot(valores)
# Out:
# <Axes: >

# %%
#2.3. Interprete o que cada gráfico indica sobre a distribuição e a dispersão dos dados.
